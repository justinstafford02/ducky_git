# %%
import random
def roll_dice():
     roll = random.randint(1,100)
     
     if roll == 100:
        #  print(f'your roll was {roll}, you lose!')
         return False
     elif roll <= 50:
        #  print(f'your roll was {roll} which is less than 50, you lose!')
         return False
     elif roll <= 100:
        #  print(f'your roll was {roll} which is between 50 and 100, you win!')
         return True

def simple_bettor(funds, initial_wager, wager_count):
      value = funds
      wager = initial_wager
      
      current_wager = 0
      
      while current_wager < wager_count:
          if roll_dice():
              value += wager
          else:
              value -= wager
           
          current_wager += 1   
          
      if value < 0:
          print(f'you are broke.')    
      print(f'Funds:, {value}')
        
x = 0
while x < 100:
    simple_bettor(10000, 100, 10000) 
    x += 1
# Out:
# Funds:, 6400
# you are broke.
# Funds:, -800
# you are broke.
# Funds:, -14000
# you are broke.
# Funds:, -10600
# you are broke.
# Funds:, -26000
# you are broke.
# Funds:, -31400
# you are broke.
# Funds:, -17200
# Funds:, 200
# you are broke.
# Funds:, -10200
# you are broke.
# Funds:, -800
# you are broke.
# Funds:, -3600
# Funds:, 400
# Funds:, 2600
# you are broke.
# Funds:, -7000
# you are broke.
# Funds:, -9800
# you are broke.
# Funds:, -14400
# you are broke.
# Funds:, -8200
# you are broke.
# Funds:, -9200
# Funds:, 3200
# Funds:, 7000
# you are broke.
# Funds:, -14200
# you are broke.
# Funds:, -19200
# you are broke.
# Funds:, -3600
# you are broke.
# Funds:, -24200
# you are broke.
# Funds:, -15600
# you are broke.
# Funds:, -9400
# you are broke.
# Funds:, -2800
# Funds:, 3800
# Funds:, 8200
# you are broke.
# Funds:, -7400
# you are broke.
# Funds:, -12400
# you are broke.
# Funds:, -13800
# you are broke.
# Funds:, -12000
# Funds:, 3800
# you are broke.
# ...

# %%
import random

def roll_dice():
    dice_score = 0
    dice_count = 0
    
    while dice_count < 100:
        roll = random.randint(1, 100)
        if 100 > roll > 50:
            dice_score += 1
        
        dice_count += 1
    
    return dice_score

print(roll_dice())
# Out:
# 53
